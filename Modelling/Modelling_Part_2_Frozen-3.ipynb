# %%
import sys
from sys import platform
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %%
if platform  == 'win32':
    sys.argv=["_", r"P:\rmahajan14\ndte_data\muni_data", "20170101", "20190930"]
if platform == 'linux' or platform == 'linux2':
    def full_path(p):
        return os.path.abspath(os.path.expanduser(p))
    sys.argv=["_", r"/mnt/d/DiDi_Ride_Data/data", r"/mnt/d/DiDi_Ride_Data/Ride_Data_Cache"]

# %%
from loader1 import *
from utils import *
from common import *
from experiment2 import *
# from sys import platform

import warnings
warnings.filterwarnings('ignore')
# Out:
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/final_df_reg.msgpack exists
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/idle_times.msgpack exists
# /mnt/c/Users/aksmi/Desktop/Drive/Fall '19/Capstone/capstone_didi/experiment2.py:215: FutureWarning: The read_msgpack is deprecated and will be removed in a future version.
# It is recommended to use pyarrow for on-the-wire transmission of pandas objects.
#   df_final, target_df = get_final_df_reg()

# %%
import time

# %% [markdown]
# Basic Coding

# %%
df_final_no_decay, target_df_no_decay = get_final_df_reg(use_cache=False, decay='No Decay')
# Out:
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/merged_orders.msgpack exists
# orders
# Decay Calculation
# No Decay
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/active_times.msgpack exists
# Decay Calculation done in 1.2803938388824463
# 1e
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/features_orders.msgpack exists
# Features created in 0.5316023826599121
# 1f
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/spatial_df.msgpack exists
# spatial
# Spatial Calculation done in 6.276373386383057

# %%
df_final_old_decay, target_df_old_decay = get_final_df_reg(use_cache=False, decay='Old Decay')
# Out:
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/merged_orders.msgpack exists
# orders
# Decay Calculation
# Old Decay
# Creating the exponential decay
# Dumping to /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/idle_times_old.msgpack
# Decay Calculation done in 43.512603998184204
# 1e
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/features_orders.msgpack exists
# Features created in 0.25661134719848633
# 1f
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/spatial_df.msgpack exists
# spatial
# Spatial Calculation done in 2.855597496032715

# %%
# Using the function create_modified_active_time_through_decay2 
# instead of create_modified_active_time_through_decay
df_final_new_decay1, target_df_new_decay1 = get_final_df_reg(use_cache=False, decay='New Decay', mult_factor=1)
df_final_new_decay10, target_df_new_decay10 = get_final_df_reg(use_cache=False, decay='New Decay', mult_factor=10)
df_final_new_decay100, target_df_new_decay100 = get_final_df_reg(use_cache=False, decay='New Decay', mult_factor=100)
# Out:
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/merged_orders.msgpack exists
# orders
# Decay Calculation
# New Decay
# Creating the exponential decay
# Dumping to /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/idle_times_new_1.msgpack
# Decay Calculation done in 46.91705131530762
# 1e
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/features_orders.msgpack exists
# Features created in 0.22458744049072266
# 1f
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/spatial_df.msgpack exists
# spatial
# Spatial Calculation done in 2.8107476234436035
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/merged_orders.msgpack exists
# orders
# Decay Calculation
# New Decay
# Creating the exponential decay
# Dumping to /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/idle_times_new_10.msgpack
# Decay Calculation done in 47.09432053565979
# 1e
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/features_orders.msgpack exists
# Features created in 0.25809526443481445
# 1f
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/spatial_df.msgpack exists
# spatial
# Spatial Calculation done in 2.853043794631958
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/merged_orders.msgpack exists
# orders
# Decay Calculation
# New Decay
# Creating the exponential decay
# Dumping to /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/idle_times_new_100.msgpack
# Decay Calculation done in 46.81869125366211
# 1e
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/features_orders.msgpack exists
# Features created in 0.5927066802978516
# 1f
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/spatial_df.msgpack exists
# spatial
# Spatial Calculation done in 4.644500970840454

# %%
df_final_new_decay100.columns
# Out:
# Index(['num_total_rides', 'num_pool_rides', '% of pool rides',
#        '(332903.267, 345801.219](3379575.462, 3389679.747]',
#        '(345801.219, 358571.469](3339057.28, 3349262.607]',
#        '(345801.219, 358571.469](3359366.892, 3369471.177]',
#        '(345801.219, 358571.469](3379575.462, 3389679.747]',
#        '(358571.469, 371341.718](3369471.177, 3379575.462]',
#        '(358571.469, 371341.718](3379575.462, 3389679.747]',
#        '(358571.469, 371341.718](3389679.747, 3399784.032]',
#        '(358571.469, 371341.718](3399784.032, 3409888.316]',
#        '(358571.469, 371341.718](3409888.316, 3419992.601]',
#        '(358571.469, 371341.718](3419992.601, 3430096.886]',
#        '(358571.469, 371341.718](3430096.886, 3440201.171]',
#        '(371341.718, 384111.968](3359366.892, 3369471.177]',
#        '(371341.718, 384111.968](3369471.177, 3379575.462]',
#        '(371341.718, 384111.968](3379575.462, 3389679.747]',
#        '(371341.718, 384111.968](3389679.747, 3399784.032]',
#        '(371341.718, 384111.968](3399784.032, 3409888.316]',
#        '(371341.718, 384111.968](3409888.316, 3419992.601]',
#        '(371341.718, 384111.968](3419992.601, 3430096.886]',
#        '(371341.718, 384111.968](3430096.886, 3440201.171]',
#        '(384111.968, 396882.217](3349262.607, 3359366.892]',
#        '(384111.968, 396882.217](3359366.892, 3369471.177]',
#        '(384111.968, 396882.217](3369471.177, 3379575.462]',
#        '(384111.968, 396882.217](3379575.462, 3389679.747]',
#        '(384111.968, 396882.217](3389679.747, 3399784.032]',
#        '(384111.968, 396882.217](3399784.032, 3409888.316]',
#        '(384111.968, 396882.217](3409888.316, 3419992.601]',
#        '(384111.968, 396882.217](3419992.601, 3430096.886]',
#        '(384111.968, 396882.217](3430096.886, 3440201.171]',
#        '(396882.217, 409652.467](3349262.607, 3359366.892]',
#        '(396882.217, 409652.467](3359366.892, 3369471.177]',
#        '(396882.217, 409652.467](3369471.177, 3379575.462]',
#        '(396882.217, 409652.467](3379575.462, 3389679.747]',
#        '(396882.217, 409652.467](3389679.747, 3399784.032]',
#        '(396882.217, 409652.467](3399784.032, 3409888.316]',
#        '(396882.217, 409652.467](3409888.316, 3419992.601]',
#        '(396882.217, 409652.467](3419992.601, 3430096.886]',
#        '(396882.217, 409652.467](3430096.886, 3440201.171]',
#        '(409652.467, 422422.716](3349262.607, 3359366.892]',
#        '(409652.467, 422422.716](3359366.892, 3369471.177]',
#        '(409652.467, 422422.716](3369471.177, 3379575.462]',
#        '(409652.467, 422422.716](3379575.462, 3389679.747]',
#        '(409652.467, 422422.716](3389679.747, 3399784.032]',
#        '(409652.467, 422422.716](3399784.032, 3409888.316]',
#        '(409652.467, 422422.716](3409888.316, 3419992.601]',
#        '(409652.467, 422422.716](3419992.601, 3430096.886]',
#        '(409652.467, 422422.716](3430096.886, 3440201.171]',
#        '(422422.716, 435192.966](3359366.892, 3369471.177]',
#        '(422422.716, 435192.966](3369471.177, 3379575.462]',
#        '(422422.716, 435192.966](3379575.462, 3389679.747]',
#        '(422422.716, 435192.966](3389679.747, 3399784.032]',
#        '(422422.716, 435192.966](3399784.032, 3409888.316]',
#        '(422422.716, 435192.966](3409888.316, 3419992.601]',
#        '(435192.966, 447963.215](3369471.177, 3379575.462]',
#        '(435192.966, 447963.215](3379575.462, 3389679.747]',
#        '(435192.966, 447963.215](3389679.747, 3399784.032]',
#        '(435192.966, 447963.215](3399784.032, 3409888.316]',
#        '(435192.966, 447963.215](3409888.316, 3419992.601]',
#        '(447963.215, 460733.465](3359366.892, 3369471.177]',
#        '(447963.215, 460733.465](3379575.462, 3389679.747]',
#        '(447963.215, 460733.465](3389679.747, 3399784.032]',
#        '(447963.215, 460733.465](3409888.316, 3419992.601]', 'inactive_time'],
#       dtype='object')

# %% [markdown]
# ### Modelling Code

# %% [markdown]
# We have till now coded the following models
#
# 1. Linear Regression
# 2. Linear Regression with L1 Regularization
# 3. Linear Regression with L2 Regularization
# 4. Random Forest Regressor

# %% [markdown]
# Now we split the data in a ratio of 75:25

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV, ElasticNet
from sklearn.ensemble import RandomForestRegressor

# %%
def build_model(df, target_df, name, seed=0):
    # regression forest
    print(f'building regression model for {name}')
    X = df    
    xtrain, xtest, ytrain, ytest = train_test_split(X, target_df['target'], random_state=seed)

    sc = StandardScaler()

    xtrain_sc = sc.fit_transform(xtrain)

    rr = RandomForestRegressor(random_state=seed)
    rr.fit(xtrain_sc, ytrain)

    xtest_sc = sc.transform(xtest)
    
    print(rr.score(xtest_sc, ytest))
    
    return rr.score(xtest_sc, ytest)

# %%
df_list = [df_final_no_decay, df_final_old_decay, df_final_new_decay1, 
           df_final_new_decay10, df_final_new_decay100]
target_df_list = [target_df_no_decay, target_df_old_decay, target_df_new_decay1, 
                  target_df_new_decay10, target_df_new_decay100]
name_list = ['no_decay', 'old_decay', 'new_decay1', 'new_decay10', 'new_decay100']

# %%
result = {}
for df, target_df, name in zip(df_list, target_df_list, name_list):
    result[name] = build_model(df, target_df, name)
# Out:
# building regression model for no_decay
# 0.446150277366595
# building regression model for old_decay
# 0.6275954233012332
# building regression model for new_decay1
# 0.5928634278076031
# building regression model for new_decay10
# 0.6694205729291004
# building regression model for new_decay100
# 0.7292180156429454

# %%
result
# Out:
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/final_df_reg.msgpack exists
# /mnt/d/DiDi_Ride_Data/Ride_Data_Cache/idle_times.msgpack exists
# {'no_decay': 0.446150277366595,
#  'old_decay': 0.6275954233012332,
#  'new_decay1': 0.5928634278076031,
#  'new_decay10': 0.6694205729291004,
#  'new_decay100': 0.7292180156429454}

# %%
df_final_old_decay.head()
# Out:
#                                   num_total_rides  num_pool_rides  \
# driver_id
# 0000131d486b69eb77ab6e9e7cca9f4c                3             0.0
# 00002724a19c5f6a54ae8d60a378997e                1             0.0
# 000042288ba964aa04d14869bd56efb6                5             0.0
# 000049d47b79747ad9927ba1bf5f4126               11             1.0
# 00005adc52a78e1630cfb50e4bd0f89e                4             0.0
#
#                                   % of pool rides  \
# driver_id
# 0000131d486b69eb77ab6e9e7cca9f4c         0.000000
# 00002724a19c5f6a54ae8d60a378997e         0.000000
# 000042288ba964aa04d14869bd56efb6         0.000000
# 000049d47b79747ad9927ba1bf5f4126         0.090909
# 00005adc52a78e1630cfb50e4bd0f89e         0.000000
#
#                                   (332903.267, 345801.219](3379575.462, 3389679.747]  \
# driver_id
# 0000131d486b69eb77ab6e9e7cca9f4c                                                0.0
# 00002724a19c5f6a54ae8d60a378997e                                                0.0
# 000042288ba964aa04d14869bd56efb6                                                0.0
# 000049d47b79747ad9927ba1bf5f4126                                                0.0
# 00005adc52a78e1630cfb50e4bd0f89e                                                0.0
#
#                                   (345801.219, 358571.469](3339057.28, 3349262.607]  \
# driver_id
# 0000131d486b69eb77ab6e9e7cca9f4c                                                0.0
# 00002724a19c5f6a54ae8d60a378997e                                                0.0
# 000042288ba964aa04d14869bd56efb6                                                0.0
# 000049d47b79747ad9927ba1bf5f4126                                                0.0
# 00005adc52a78e1630cfb50e4bd0f89e                                                0.0
#
#                                   (345801.219, 358571.469](3359366.892, 3369471.177]  \
# driver_id
# 0000131d486b69eb77ab6e9e7cca9f4c                                                0.0
# 00002724a19c5f6a54ae8d60a378997e                                                0.0
# 000042288ba964aa04d14869bd56efb6                                                0.0
# 000049d47b79747ad9927ba1bf5f4126                                                0.0
# 00005adc52a78e1630cfb50e4bd0f89e                                                0.0
#
#                                   (345801.219, 358571.469](3379575.462, 3389679.747]  \
# driver_id
# 0000131d486b69eb77ab6e9e7cca9f4c                                                0.0
# 00002724a19c5f6a54ae8d60a378997e                                                0.0
# 000042288ba964aa04d14869bd56efb6                                                0.0
# 000049d47b79747ad9927ba1bf5f4126                                                0.0
# 00005adc52a78e1630cfb50e4bd0f89e                                                0.0
#
#                                   (358571.469, 371341.718](3369471.177, 3379575.462]  \
# driver_id
# 0000131d486b69eb77ab6e9e7cca9f4c                                                0.0
# 00002724a19c5f6a54ae8d60a378997e                                                0.0
# 000042288ba964aa04d14869bd56efb6                                                0.0
# 000049d47b79747ad9927ba1bf5f4126                                                0.0
# 00005adc52a78e1630cfb50e4bd0f89e                                                0.0
#
#                                   (358571.469, 371341.718](3379575.462, 3389679.747]  \
# driver_id
# 0000131d486b69eb77ab6e9e7cca9f4c                                                0.0
# 00002724a19c5f6a54ae8d60a378997e                                                0.0
# 000042288ba964aa04d14869bd56efb6                                                0.0
# 000049d47b79747ad9927ba1bf5f4126                                                0.0
# 00005adc52a78e1630cfb50e4bd0f89e                                                0.0
#
#                                   (358571.469, 371341.718](3389679.747, 3399784.032]  \
# driver_id
# 0000131d486b69eb77ab6e9e7cca9f4c                                                0.0
# 00002724a19c5f6a54ae8d60a378997e                                                0.0
# 000042288ba964aa04d14869bd56efb6                                                0.0
# 000049d47b79747ad9927ba1bf5f4126                                                0.0
# 00005adc52a78e1630cfb50e4bd0f89e                                                0.0
#
#                                